# %%
import json
import os
import pandas as pd

# %%
file_path = r"D:\MyProjects\data-mining-itc\Data\data.json"
with open(file_path) as f:
    data = json.loads(f.read())

# %%
{k: v['Top 10 Countries'] if 'Top 10 Countries' in v else {'Null': 1} for k, v in data.items()}
# Out:
# {'SPY': {'United States': 1.0, 'Canada': 0.0},
#  'IVV': {'United States': 1.0, 'Canada': 0.0},
#  'VTI': {'United States': 0.9991, 'Canada': 0.0009, 'United Kingdom': 0.0},
#  'VOO': {'United States': 1.0, 'Canada': 0.0},
#  'QQQ': {'United States': 0.9771,
#   'China': 0.0107,
#   'Hong Kong': 0.009,
#   'Netherlands': 0.0032,
#   'Canada': 0.0},
#  'VEA': {'Japan': 0.2233,
#   'United Kingdom': 0.1225,
#   'France': 0.0811,
#   'Switzerland': 0.0772,
#   'Germany': 0.0759,
#   'Canada': 0.0756,
#   'Australia': 0.064,
#   'Korea, Republic of': 0.0579,
#   'Netherlands': 0.033,
#   'Sweden': 0.0328},
#  'IEFA': {'Japan': 0.256,
#   'United Kingdom': 0.1502,
#   'France': 0.0971,
#   'Switzerland': 0.0906,
#   'Germany': 0.0875,
#   'Australia': 0.073,
#   'Sweden': 0.0391,
#   'Netherlands': 0.0384,
#   'Hong Kong': 0.0297,
#   'Denmark': 0.0246},
#  'AGG': {'United States': 0.9325,
#   'United Kingdom': 0.0119,
#   'Canada': 0.0117,
#   'Japan': 0.006,
#   'Germany': 0.0037,
# ...

# %%
data['SPY']['Top 10 Countries']
# Out:
# {'United States': 1.0, 'Canada': 0.0}
